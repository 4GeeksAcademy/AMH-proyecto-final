# %% [markdown]
# ## Adquisicion de datos de la AEMET

# %%
#Librerias
import requests
import pandas as pd
import json

# %%
# Tu API Key de AEMET
api_key = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhbGJhZWJhdWx1ekBob3RtYWlsLmNvbSIsImp0aSI6IjU3YWYzYTM1LTdhOTMtNDg3Ny05MWU4LWY3NDM1NWU4MzU2ZCIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzI3NDU3NzA3LCJ1c2VySWQiOiI1N2FmM2EzNS03YTkzLTQ4NzctOTFlOC1mNzQzNTVlODM1NmQiLCJyb2xlIjoiIn0.KjwIE5_jQfA-JovEc8nfN9kcJ_lDwrQf6mweqSN5KvQ"

# Creamos un listado con las comunidades y su id
'''
estaciones_ids = [
    {"comunidad": "Andalucía", "id": "2003"},
    {"comunidad": "Aragón", "id": "2001"},
    {"comunidad": "Asturias", "id": "3301"},
    {"comunidad": "Islas Baleares", "id": "0701"},
    {"comunidad": "Canarias", "id": "3002"},
    {"comunidad": "Cantabria", "id": "3901"},
    {"comunidad": "Castilla y León", "id": "4701"},
    {"comunidad": "Castilla-La Mancha", "id": "4501"},
    {"comunidad": "Cataluña", "id": "0801"},
    {"comunidad": "Extremadura", "id": "0601"},
    {"comunidad": "Galicia", "id": "1501"},
    {"comunidad": "La Rioja", "id": "2601"},
    {"comunidad": "Madrid", "id": "2801"},
    {"comunidad": "Murcia", "id": "3001"},
    {"comunidad": "Navarra", "id": "3101"},
    {"comunidad": "País Vasco", "id": "0101"},
    {"comunidad": "Valencia", "id": "4601"}
]
'''
#Almacen de datos
df_temp = pd.DataFrame(columns=['fecha', 'tmed'])

# Definir el intervalo de fechas
start_date = "2023-09-01T00:00:00UTC" 
end_date = "2023-09-02T23:59:59UTC"

# %%
# URL para listar estaciones
url_estaciones = f'https://opendata.aemet.es/opendata/sh/bbbb0388/?api_key={api_key}'
# Hacer la solicitud
response = requests.get(url_estaciones)

# Comprobar el código de estado
if response.status_code == 200:
    print("Solicitud exitosa.")
    print(response.json())
    json_text=response.json()
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Solicitud exitosa.
# ...

# %%
df = pd.DataFrame(json_text, columns=['fecha','tmed'])

df
# Out:
#           fecha  tmed
# 0    2019-07-01  24,6
# 1    2019-07-02  24,8
# 2    2019-07-03  25,7
# 3    2019-07-04  25,6
# 4    2019-07-05  25,4
# ..          ...   ...
# 179  2019-12-27  12,0
# 180  2019-12-28  11,0
# 181  2019-12-29  12,3
# 182  2019-12-30  11,6
# 183  2019-12-31  10,8
#
# [184 rows x 2 columns]

# %%
df_temp=df = pd.concat([df_temp, df])

# %%
df_temp
# Out:
#           fecha  tmed
# 0    2023-07-01  22,6
# 1    2023-07-02  24,6
# 2    2023-07-03  24,6
# 3    2023-07-04  25,1
# 4    2023-07-05  24,4
# ..          ...   ...
# 179  2019-12-27  12,0
# 180  2019-12-28  11,0
# 181  2019-12-29  12,3
# 182  2019-12-30  11,6
# 183  2019-12-31  10,8
#
# [1729 rows x 2 columns]

# %%
df['fecha'] = pd.to_datetime(df['fecha'] , dayfirst=False)

# %%
df_temp_sorted = df.sort_values(by='fecha')

# Resetear el índice si es necesario
df_sorted = df_temp_sorted.reset_index(drop=True)

# %%
# Asegurarse de que la columna 'prec' es de tipo string antes de reemplazar
df['prec'] = df['prec'].astype(str).str.replace(',', '.')

# Convertir la columna 'prec' a numérica
df['prec'] = pd.to_numeric(df['prec'])

# Aplicar el filtro para seleccionar valores de 'prec' mayores a 0 y sumar
suma = df[df['prec'] > 0.00]['prec'].sum()

print(suma)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prec'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Texto JSON
json_text = """
[{
  "fecha" : "2019-01-01",
  "indicativo" : "0201D",
  "nombre" : "BARCELONA, PORT OLÍMPIC",
  "provincia" : "BARCELONA",
  "altitud" : "26",
  "tmed" : "11,4",
  "prec" : "0,0",
  "tmin" : "6,6",
  "horatmin" : "03:40",
  "tmax" : "16,2",
  "horatmax" : "12:30",
  "dir" : "01",
  "velmedia" : "3,1",
  "racha" : "6,4",
  "horaracha" : "07:30",
  "hrMedia" : "76",
  "hrMax" : "90",
  "horaHrMax" : "20:00",
  "hrMin" : "59",
  "horaHrMin" : "22:30"
}, {
  "fecha" : "2019-01-02",
  "indicativo" : "0201D",
  "nombre" : "BARCELONA, PORT OLÍMPIC",
  "provincia" : "BARCELONA",
  "altitud" : "26",
  "tmed" : "11,2",
  "prec" : "0,0",
  "tmin" : "6,6",
  "horatmin" : "Varias",
  "tmax" : "15,7",
  "horatmax" : "14:50",
  "dir" : "01",
  "velmedia" : "2,2",
  "racha" : "6,9",
  "horaracha" : "06:10",
  "hrMedia" : "52",
  "hrMax" : "66",
  "horaHrMax" : "Varias",
  "hrMin" : "40",
  "horaHrMin" : "14:40"
}]
"""

# Cargar el JSON en un objeto de Python
data = json.loads(json_text)

# Crear el DataFrame seleccionando las columnas deseadas
df = pd.DataFrame(data, columns=['fecha', 'tmed', 'prec', 'velmedia'])

# Mostrar el DataFrame
df
# Out:
#         fecha  tmed prec velmedia
# 0  2019-01-01  11,4  0,0      3,1
# 1  2019-01-02  11,2  0,0      2,2

# %%
# Iterar sobre cada ID de estación
for estacion in estaciones_ids:
    estacion_id = estacion['id']
    
    # Definir la URL del endpoint de AEMET
    #url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/dia/{estacion_id}/?api_key={api_key}&start_date={start_date}&end_date={end_date}"
    url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/dia/{estacion_id}/?api_key={api_key}"
    response = requests.get(url)
    
    if response.status_code == 200:

        data_url = response.json()['datos']
        data_response = requests.get(data_url)
        
        if data_response.status_code == 200:
            data = data_response.json()
            for record in data:
                record['comunidad'] = estacion['comunidad']  # Añadir las comunidades a los registros 
            all_data.extend(data)  # Añadir los datos al listado
        else:
            print(f"Error al obtener los datos de la estación {estacion_id}: {data_response.status_code}")
    else:
        print(f"Error en la solicitud para la estación {estacion_id}: {response.status_code}, URL: {url}")

if all_data:
    df = pd.DataFrame(all_data)
    
    df['fecha'] = pd.to_datetime(df['fecha'])
    df.set_index('fecha', inplace=True)
    
else:
    print("No se obtuvieron datos.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Iterar sobre cada ID de estación
# ----> 2 for estacion in estaciones_ids:
#       3     estacion_id = estacion['id']
#       5     # Definir la URL del endpoint de AEMET
#       6     #url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/dia/{estacion_id}/?api_key={api_key}&start_date={start_date}&end_date={end_date}"
#
# NameError: name 'estaciones_ids' is not defined

# %%
df_temp_sorted
# Out:
#         fecha  tmed
# 0  2019-01-01  11,4
# 1  2019-01-02  11,2
# 2  2019-01-03   9,2
# 3  2019-01-04   8,4
# 4  2019-01-05  11,4
# ..        ...   ...
# 81 2024-09-20  20,0
# 82 2024-09-21  20,6
# 83 2024-09-22  21,2
# 84 2024-09-23  20,8
# 85 2024-09-24  22,4
#
# [1729 rows x 2 columns]

# %%
df_temp_sorted.to_csv("../data/processed/prueba_df_temp.csv", index = False)
